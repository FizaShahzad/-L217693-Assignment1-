# %% [markdown]
#  defining the procedure here

# %%
def check(arr):
    point ="false"
    point2 = "true"
    N = len(arr)
    row = set()
    col = set();
    flag = 1;
    for i in range(N):
        row = set()
        col = set();
        for j in range(N):
            # Inserting the elements
            # to row set and column set
            col.add(arr[j][i]);
            row.add(arr[i][j]);

        # Checking the size of each
        # row and column and if it is
        # equal or not
        if (len(col) != N or len(row) != N):
            flag = 0;
    if (flag ==0):
        return point;
    else:
        return point2;

# %% [markdown]
# Driver Code

# %%
test1 = [[1, 2, 3],
        [2, 3, 1],
        [3, 1, 2]]

# %%
test2 = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]

# %%
test3 = [['a', 'b', 'c'],
        ['b', 'c', 'a'],
        ['c', 'a', 'b']]
#checking
print(check(test1))
print(check(test2))
print(check(test3))
